# %%
# Install packages in the current Jupyter kernel that the files rely on
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.4.3/libexec/bin/python3.10 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.4.3/libexec/bin/python3.10 -m pip install --upgrade pip' command.

# %%
from makeup_guide_face_transforms import plot_from_file

# %% [markdown]
# Run the cell below to get the names of all the files where data is stored in.

# %%
FILE_NAMES = ['horizontal_centering_data_1.txt',
              'horizontal_centering_data_2.txt',
              'horizontal_centering_data_3.txt',
              'centering_data_1.txt',
              'horizontal_sweep_data_1.txt',
              'vertical_centering_data_1.txt',
              'vertical_sweep_data_1.txt']

# %% [markdown]
# ## Plot the horizontal centering data
#
# This represents the face transform data for moving the face horizontally within a general "center" range.

# %%
plot_from_file(FILE_NAMES[0])
plot_from_file(FILE_NAMES[1])
plot_from_file(FILE_NAMES[2])
# Out:
# [0,0], max: 0.08964208, min: -0.00768441
# [0,1], max: 0.9995299, min: 0.8974988
# [0,2], max: 0.44101644, min: -0.288458
# [0,3], max: 0.0, min: 0.0
# [1,0], max: -0.9959703, min: -0.99981093
# [1,1], max: 0.089014135, min: -0.0071162446
# [1,2], max: 0.010939436, min: -0.06876826
# [1,3], max: 0.0, min: 0.0
# [2,0], max: 0.002736727, min: -0.0768837
# [2,1], max: 0.28969708, min: -0.4396743
# [2,2], max: 0.999375, min: 0.89486045
# [2,3], max: 0.0, min: 0.0
# [3,0], max: 0.037497, min: 0.015831284
# [3,1], max: 0.017979167, min: -0.019553015
# [3,2], max: -0.38958204, min: -0.4163996
# [3,3], max: 1.0000001, min: 0.9999999
# [0,0], max: 0.042276353, min: -0.026610253
# [0,1], max: 0.9994438, min: 0.9644229
# [0,2], max: 0.26302132, min: -0.026456768
# [0,3], max: 0.0, min: 0.0
# [1,0], max: -0.9975406, min: -0.9993447
# [1,1], max: 0.051137988, min: -0.01687132
# [1,2], max: -0.0018431918, min: -0.058421016
# [1,3], max: 0.0, min: 0.0
# [2,0], max: -0.001798254, min: -0.059877098
# ...

# %% [markdown]
# The first plot is where i turned the most. It is a larger range, but perhaps shouldn't be considered as much as the other plots.
#
# 0, 2 and 2, 1 seemed to have the most variation for horizontal centering, so that is what will be used in deriving this.

# %% [markdown]
# ## Plot the vertical centering data
#
# This represents the face transform data for moving the face vertically within a general "center" range.

# %%
plot_from_file(FILE_NAMES[5])
# Out:
# [0,0], max: 0.062497493, min: 0.018769965
# [0,1], max: 0.9993295, min: 0.9967317
# [0,2], max: 0.07586967, min: 0.015694272
# [0,3], max: 0.0, min: 0.0
# [1,0], max: -0.95035696, min: -0.99962896
# [1,1], max: 0.060090467, min: 0.023288911
# [1,2], max: 0.20422482, min: -0.30840793
# [1,3], max: 0.0, min: 0.0
# [2,0], max: 0.20306128, min: -0.30886307
# [2,1], max: -0.0049751634, min: -0.07437727
# [2,2], max: 0.9986921, min: 0.95109326
# [2,3], max: 0.0, min: 0.0
# [3,0], max: 0.018073557, min: -0.011969689
# [3,1], max: 0.009663296, min: -0.001376576
# [3,2], max: -0.38301608, min: -0.41535878
# [3,3], max: 1.0000001, min: 0.9999999

# %% [markdown]
# ## Plot the horizontal and vertical sweep data
#
# This represents the face transform data for moving the face horizontally and vertically (respectively) for a full left-right and up-down sweep of the face.

# %%
plot_from_file(FILE_NAMES[4])
plot_from_file(FILE_NAMES[6])
# Out:
# [0,0], max: 0.13167793, min: -0.033108484
# [0,1], max: 0.9984546, min: 0.8239073
# [0,2], max: 0.56577384, min: -0.5079235
# [0,3], max: 0.0, min: 0.0
# [1,0], max: -0.9828494, min: -0.9940298
# [1,1], max: 0.08302799, min: 0.019699698
# [1,2], max: -0.1024606, min: -0.17208198
# [1,3], max: 0.0, min: 0.0
# [2,0], max: -0.06549903, min: -0.13466154
# [2,1], max: 0.518737, min: -0.5655206
# [2,2], max: 0.9933933, min: 0.81700724
# [2,3], max: 0.0, min: 0.0
# [3,0], max: 0.03600395, min: 0.02329433
# [3,1], max: 0.043248083, min: -0.013385946
# [3,2], max: -0.35850376, min: -0.3703219
# [3,3], max: 1.0000001, min: 0.9999998
# [0,0], max: 0.06581581, min: 0.025786255
# [0,1], max: 0.99703795, min: 0.9911146
# [0,2], max: 0.12905309, min: 0.053109933
# [0,3], max: 0.0, min: 0.0
# [1,0], max: -0.8370952, min: -0.9985162
# [1,1], max: 0.08765306, min: 0.017504994
# [1,2], max: 0.42282957, min: -0.5419997
# [1,3], max: 0.0, min: 0.0
# [2,0], max: 0.4186373, min: -0.5464441
# ...
